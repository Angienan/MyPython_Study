# %%
import pandas as pd
#构造数据集 ---DataFame
df = pd.DataFrame([
    {"姓名": "张三", "语文": 80, "数学": 90, "英语": 75},
    {"姓名": "李四", "语文": 75, "数学": 85, "英语": 90},
    {"姓名": "王五", "语文": 90, "数学": 80, "英语": 85},
    {"姓名": "赵六", "语文": 60, "数学": 70, "英语": 75}
])

# 统计计算
f"语文平均分:{df['语文'].mean()},最高分:{df['语文'].max()},最低分:{df['语文'].min()}"
# Out:
# '语文平均分:76.25,最高分:90,最低分:60'

# %% [markdown]
# **入门**
