# %%
import pandas as pd
#构造数据集 ---DataFame
df1 = pd.DataFrame([
    {"姓名": "张三", "语文": 80, "数学": 90, "英语": 75},
    {"姓名": "李四", "语文": 75, "数学": 85, "英语": 90},
    {"姓名": "王五", "语文": 90, "数学": 80, "英语": 85},
    {"姓名": "赵六", "语文": 60, "数学": 70, "英语": 75}
])

df2 = pd.DataFrame({
    '姓名':['张三','李四','王五'],
    '语文':[85,75,90],
    '数学':[90,85,70],
    '英语':[78,85,90]
})

df3 = pd.DataFrame([
    ['张三',85,92,78],
    ['李四',75,85,85],
    ['王五',90,75,90]
]).columns=['姓名','语文','数学','英语']

df4 = pd.DataFrame([
    ['张三',85,92,78],
    ['李四',75,85,85],
    ['王五',90,75,90]
],columns=['姓名','语文','数学','英语'])

df1
#DataFrame 常见属性
df1.index.to_list()

df1.columns.to_list()

df1.values.tolist()

df1.size
df1.dtypes

df1.shape
# Out:
# (4, 4)
