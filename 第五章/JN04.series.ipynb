# %%
import pandas as pd

#Series 一维数据

s = pd.Series([10,20,30,40],index=['a','b','c','d'])
s2 = pd.Series({'a':10,'b':20,'c':30,'d':40})


df1 = pd.DataFrame([
    {"姓名": "张三", "语文": 80, "数学": 90, "英语": 75},
    {"姓名": "李四", "语文": 75, "数学": 85, "英语": 90},
    {"姓名": "王五", "语文": 90, "数学": 80, "英语": 85},
    {"姓名": "赵六", "语文": 60, "数学": 70, "英语": 75}
])
s3  = df1['语文']
s4 = df1['数学']

s4
# Out:
# 0    90
# 1    85
# 2    80
# 3    70
# Name: 数学, dtype: int64
